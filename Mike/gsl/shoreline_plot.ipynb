# %%
import numpy as np
import mikeio
import xarray as xr
import pandas as pd

# %% [markdown]
# ## Event 1

# %% [markdown]
# ### Difference between current and future

# %%
import mikeio.generic
fn_diff = "../future_mpissp5/mesh2_one-coupling/2070_10-10_10-15_one-way/diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2070_10-10_10-15_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2070_10-10_10-15_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2000-9-29_10-3_onWayCoupling_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2000-9-29_10-3_onWayCoupling_correctedPressure/Q_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Plotting

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event1.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event1.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.25, vmax=0.25, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\1277286527.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event1.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 2

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event2_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2066-9-28_10-3_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2066-9-28_10-3_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2000_9-18_9-22_modHo_oneCoupling_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2000_9-18_9-22_modHo_oneCoupling_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event2.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event2.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.24, vmax=0.24, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\3089794589.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event2.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 3

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event3_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2062-9-30_10-5_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2062-9-30_10-5_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/1992-10-4_10-8_one-way-coupling_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/1992-10-4_10-8_one-way-coupling_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event3.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event3.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.245, vmax=0.245, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\1693722133.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event3.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 4

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event4_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2068-8-15_8-20_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2068-8-15_8-20_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2011-9-29_10-3_one-coupling_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2011-9-29_10-3_one-coupling_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 59.45it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event4.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event4.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.25, vmax=0.25, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\1713054633.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event4.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 5

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event5_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2057-10-22_10-27_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2057-10-22_10-27_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2008-10-13_10-17_one-way_correctedPressue/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2008-10-13_10-17_one-way_correctedPressue/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event5.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event5.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.285, vmax=0.285, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\2688881328.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event5.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 6

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event6_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2066-9-11_9-16/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2066-9-11_9-16/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2020-6-18_6-22_one-way_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2020-6-18_6-22_one-way_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event6.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event6.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.2475, vmax=0.2475, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\3909086268.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event6.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 7

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event7_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2064-6-9-6-14_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2064-6-9-6-14_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2001-11-19_11-23_one-way_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2001-11-19_11-23_one-way_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event7.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event7.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.2375, vmax=0.2375, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\580333367.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event7.txt',  sep='\s+', skiprows=None, header=None)

# %% [markdown]
# ## Event 8

# %%
import mikeio.generic
fn_diff = "./shoreline_difference_eta/event8_diff_zeta_max.dfsu"
fn = "../future_mpissp5/mesh2_one-coupling/2051-8-23_8-28_one-way/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_f = "../future_mpissp5/mesh2_one-coupling/2051-8-23_8-28_one-way/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_f, q=[0.999])

fn = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2020-6-30_7-4_one-way_correctedPressure/proj.mfm"+" "+"-"+" "+"Result Files"+"/output_elev.dfsu"
fn_q_c = "../main_basin_and_east_arm_3rd-stage/one-wave-coupling-wave_modH0_correctedPressure/2020-6-30_7-4_one-way_correctedPressure/zeta_max_out.dfsu"
mikeio.generic.quantile(fn, fn_q_c, q=[0.999])

mikeio.generic.diff(fn_q_f, fn_q_c, fn_diff)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
### This interpolation is done by post-processing software
# bnd_elem_ind = pd.read_csv(r'./boundary_element',  sep='\s+', skiprows=None, header=None)
# bnd_elem_coord = pd.read_csv(r'./boundary_element_coords',  sep='\s+', skiprows=None, header=None)
# shoreline_elev = np.zeros_like(bnd_elem_ind)+1.0e-8
# for i in range(len(bnd_elem_ind)):
#     ind = bnd_elem_ind[0][i]-1
#     shoreline_elev[i] = elev_res[ind]
#     print(i)
shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event8.txt',  sep='\s+', skiprows=None, header=None)

# do the scatter plot
fig_str = r'./shoreline_difference_eta/event8.jpg'
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20.5
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)
plt.rcParams['text.usetex'] = True
# plt.figure().set_figwidth(20)
plt.tight_layout()
# ax = ds.Current_speed[step].plot(figsize=(10,10))
# fig, ax = plt.subplots(figsize=(18, 7.2))
import geopandas as gpd
import pandas as pd
geo_df_total = pd.DataFrame()
geo_df = gpd.read_file('shoreline_2.geojson')
geo_df_total = gpd.GeoDataFrame( pd.concat( [geo_df_total, geo_df], ignore_index=True) )
geo_axes = geo_df_total.plot(facecolor='none', edgecolor='darkolivegreen', linewidth=1.25, figsize=(12, 8.0), zorder=15)
geo_axes.set_xlabel("Longitude", fontsize=21)
geo_axes.set_ylabel("Latitude", fontsize=21)
stat_lon1 = [-114.348]
stat_lat1 = [62.4355]
stat_lon2 = [-115.6395]
stat_lat2 = [60.8704]
stat_lon3 = [-113.52]
stat_lat3 = [61.2046]
stat_lon4 = [-110.7071]
stat_lat4 = [62.4284]
obs_lon1 = [-114.13]
obs_lat1 = [61.98]
obs_lon2 = [-115.31]
obs_lat2 = [61.18]
geo_axes.scatter(stat_lon1, stat_lat1, zorder=10, marker='*', facecolors='none', color='xkcd:tree green', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon2, stat_lat2, zorder=10, marker='*', facecolors='none', color="xkcd:hot pink", s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon3, stat_lat3, zorder=10, marker='*', facecolors='none', color='xkcd:bright purple', s = 600, linewidth=2.9)
geo_axes.scatter(stat_lon4, stat_lat4, zorder=10, marker='*', facecolors='none', color='xkcd:mustard', s = 600, linewidth=2.9)
geo_axes.scatter(shoreline_elev[0], shoreline_elev[1], c=shoreline_elev[2], vmin=-0.25, vmax=0.2675, cmap='coolwarm', s=128)

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')
geo_axes.set_xlim([-117.1, -108.95])
geo_axes.set_ylim([60.8, 63.03])
plt.yticks(np.arange(61.0, 63.03, 0.5))
# geo_axes.savefig(fig_str, dpi=600)
plt.savefig(fig_str, dpi=600)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\byy\AppData\Local\Temp\ipykernel_12992\1604339944.py:9: SyntaxWarning: invalid escape sequence '\s'
#   shoreline_elev = pd.read_csv(r'./shoreline_difference_eta/event8.txt',  sep='\s+', skiprows=None, header=None)
